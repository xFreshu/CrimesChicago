# %%
# Importowanie funkcji z pliku processed_data.py
from src.preprocess_data import preprocess_data
# Ścieżki do plików CSV
input_csv_path = "../data/raw/Chicago_Crimes_2012_to_2017.csv"
output_csv_path = "../data/processed/Chicago_Crimes_2012_to_2017_processed.csv"

# Uruchomienie funkcji przetwarzającej dane
processed_df = preprocess_data(input_csv_path, output_csv_path)
# Out:
# Loading raw data...
# Raw data loaded successfully.
# Preprocessing data...
# Processed data saved to: ../data/processed/Chicago_Crimes_2012_to_2017_processed.csv
# Sample of processed data:
#          ID Case Number                Date            Primary Type  \
# 0  10508693    HZ250496 2016-05-03 23:40:00                 BATTERY
# 1  10508695    HZ250409 2016-05-03 21:40:00                 BATTERY
# 2  10508697    HZ250503 2016-05-03 23:31:00  PUBLIC PEACE VIOLATION
# 3  10508698    HZ250424 2016-05-03 22:10:00                 BATTERY
# 4  10508699    HZ250455 2016-05-03 22:00:00                   THEFT
#
#                Description Location Description  Arrest  Domestic  Beat  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  1022
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True   313
# 2         RECKLESS CONDUCT               STREET   False     False  1524
# 3                   SIMPLE             SIDEWALK   False     False  1532
# ...

# %%
# Wyświetlenie przykładowych przetworzonych danych
if processed_df is not None:
    print("Sample of processed data:")
    display(processed_df.head())
else:
    print("Data processing failed.")
# Out:
# Sample of processed data:
#          ID Case Number                Date            Primary Type  \
# 0  10508693    HZ250496 2016-05-03 23:40:00                 BATTERY
# 1  10508695    HZ250409 2016-05-03 21:40:00                 BATTERY
# 2  10508697    HZ250503 2016-05-03 23:31:00  PUBLIC PEACE VIOLATION
# 3  10508698    HZ250424 2016-05-03 22:10:00                 BATTERY
# 4  10508699    HZ250455 2016-05-03 22:00:00                   THEFT
#
#                Description Location Description  Arrest  Domestic  Beat  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  1022
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True   313
# 2         RECKLESS CONDUCT               STREET   False     False  1524
# 3                   SIMPLE             SIDEWALK   False     False  1532
# 4           $500 AND UNDER            RESIDENCE   False      True  1523
#
#    District  Ward  Community Area FBI Code   Latitude  Longitude  Year  Month  \
# ...
